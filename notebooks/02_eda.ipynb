# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/cleaned_student_data.csv")
df.head()
# Out:
#   Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0       S147    Male                    31        68.267841                86
# 1       S136    Male                    16        78.222927                73
# 2       S209  Female                    21        87.525096                74
# 3       S458  Female                    27        92.076483                99
# 4       S078  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
# ...

# %% [markdown]
# df.hist(figsize=(10,8))
# plt.show()

# %% [markdown]
# # Exploration of Weekly Study Hours

# %%
df["Study_Hours_per_Week"].value_counts().sort_index()
# Out:
# 10    23
# 11    16
# 12    20
# 13    21
# 14    26
# 15    17
# 16    16
# 17    15
# 18    13
# 19    20
# 20    18
# 21    36
# 22    26
# 23    15
# 24    15
# 25    22
# 26    20
# 27    24
# 28    26
# 29    20
# 30    23
# 31    31
# 32    26
# 33    19
# 34    28
# 35    49
# 36    14
# 37    34
# 38    44
# 39    31
# Name: Study_Hours_per_Week, dtype: int64

# %% [markdown]
# ### Study hours insights
# Study hours are not uniformly distributed. There is a clear concentration in the higher range (30–39 hours per week), with the highest frequency around 35 hours. This suggests that many students in the dataset report relatively high study time, which may influence model predictions toward higher study patterns.

# %% [markdown]
# # Exploration of Attendance Rate

# %%
df["Attendance_Rate"].value_counts().sort_index()
# Out:
# 50.116970    1
# 50.129751    1
# 50.135545    1
# 50.262691    1
# 50.265000    1
#             ..
# 99.436439    2
# 99.546474    2
# 99.862777    2
# 99.884631    2
# 99.967675    1
# Name: Attendance_Rate, Length: 500, dtype: int64

# %%
sns.histplot(df["Attendance_Rate"], bins=20, kde=True)
# Out:
# <AxesSubplot:xlabel='Attendance_Rate', ylabel='Count'>

# %% [markdown]
# ### Attendance Insights
# Attendance rate is continuously distributed with many unique values across the range. While it spans from approximately 50% to 100%, there is a slight concentration toward higher values, suggesting that most students maintain relatively high attendance. This feature provides good variability for modeling.

# %% [markdown]
# # Exploration of Past Exam Scores

# %%
df["Past_Exam_Scores"].value_counts().sort_index()
# Out:
# 50      4
# 51      7
# 52     13
# 53      9
# 54      8
# 55     12
# 56      9
# 57     11
# 58     12
# 59      8
# 60     14
# 61     12
# 62     17
# 63      9
# 64     25
# 65      9
# 66     14
# 67     20
# 68      5
# 69     13
# 70      6
# 71     11
# 72      6
# 73     22
# 74     23
# 75     10
# 76      8
# 77      9
# 78     24
# 79     14
# 80      8
# 81     19
# 82     13
# 83     20
# 84     15
# 85      9
# 86     12
# 87     13
# 88     24
# 89     16
# 90     16
# 91     12
# 92     15
# 93     22
# 94     19
# 95     19
# 96     24
# 97     12
# 98     23
# 99     17
# 100    16
# Name: Past_Exam_Scores, dtype: int64

# %%
df[["Past_Exam_Scores", "Final_Exam_Score"]].corr()
# Out:
#                   Past_Exam_Scores  Final_Exam_Score
# Past_Exam_Scores          1.000000          0.489516
# Final_Exam_Score          0.489516          1.000000

# %% [markdown]
# ### Exam score insights
# Past exam scores are concentrated in the higher range (70–100), indicating that most students in the dataset have strong prior academic performance. The distribution is negatively skewed, with fewer students scoring in the lower range.
# However, it shows a moderate correlation (0.49) with final scores, suggesting that while prior performance influences outcomes, it does not fully determine them. This indicates that other features such as study hours and attendance also contribute meaningfully to student performance.
